# %%
#read this dataset

# %% [raw]
# 1.Explain the key features of Python that make it a popular choice for programming ?
#
#
# Ans:-
# Here following are some of the features in Python that make it a popular choice for programming:-
#
# 1. Easy to Code
# 2. Easy to Read
# 3. Free and Open-Source
# 4. Robust Standard Library
# 5. Interpreted
# 6. Portable
# 7. Object-Oriented and Procedure-Oriented
# 8. Extensible
# 9. Expressive
# 10. Support for GUI
# 11. Dynamically Typed
# 12. High-level Language
# 13. Simplify Complex Software Development
# 14. Other Advanced Programming Features
# 15. Dynamic Binding
# 16. Strong Community Support

# %% [raw]
# 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a
# program ?
#
# Ans:-
#
# 1. 'if','elif','else':Used for conditional statements.
#
#
# x = 10
# if x > 5:
#     print("x is greater than 5")
# elif x == 5:
#     print("x is 5")
# else:
#     print("x is less than 5")
#
#
#
# 2.'for','while','break','continue':Used for looping and controlling loop execution.
#
#
# # Using 'for' loop
# for i in range(5):
#     print(i)
#
# # Using 'while' loop
# count = 0
# while count < 5:
#     print(count)
#     count += 1
#
# # Using 'break' to exit a loop
# for i in range(10):
#     if i == 5:
#         break
#     print(i)
#
# # Using 'continue' to skip an iteration
# for i in range(10):
#     if i % 2 == 0:
#         continue
#     print(i)  # This prints only odd numbers
#
#
# 3.'def','return': Used for defining and returning from functions.
#
#
# def greet(name):
#     return f"Hello, {name}!"
#
# message = greet("Alice")
# print(message)  # Output: Hello, Alice!
#
#
# 4.'class','self': Used for defining classes and referring to instance attributes.
#
#
# class Dog:
#     def __init__(self, name):
#         self.name = name
#
#     def bark(self):
#         return f"{self.name} says woof!"
#
# my_dog = Dog("Buddy")
# print(my_dog.bark())  # Output: Buddy says woof!
#
#
# 5.'import','from','as': Used for importing modules and their components.
#
#
# import math
# print(math.sqrt(16))  # Output: 4.0
#
# from datetime import datetime
# print(datetime.now())
#
# import numpy as np
# array = np.array([1, 2, 3])
# print(array)  # Output: [1 2 3]
#
#
# 6.'try','except','finally','raise': Used for handling exceptions and errors.
#
#
# try:
#     result = 10 / 0
# except ZeroDivisionError:
#     print("You can't divide by zero!")
# finally:
#     print("This will always execute")
#
# # Raising an exception
# def divide(a, b):
#     if b == 0:
#         raise ValueError("Cannot divide by zero")
#     return a / b
# 7.'with': Used for resource management and ensures that resources are properly cleaned up
#
#
# with open('file.txt', 'r') as file:
#     content = file.read()
#     print(content)
# # The file is automatically closed after the block is executed
#
#
# 8.'and','or','not': Logical operators used for boolean expressions
#
#
# a = True
# b = False
#
# print(a and b)  # Output: False
# print(a or b)   # Output: True
# print(not a)    # Output: False

# %% [raw]
# 3. Compare and contrast mutable and immutable objects in Python with examples.
#
#
#
# In Python, objects can be categorized into two main types based on their mutability: mutable and immutable.
# Understanding the differences between these types is crucial for effective programming and avoiding unintended side effects.
#
# Mutable Objects
# Mutable objects can be changed after they are created. This means you can modify their content without creating a new object.
# Common examples of mutable objects in Python include:
#
# .Lists
# .Dictionaries
# .Sets
#
# Examples:-
#
# 1.List
#
# my_list = [1, 2, 3]
# print("Original list:", my_list)
#
# my_list[0] = 10  # Modifying the first element
# print("Modified list:", my_list)
#
#
# OUTPUT:-
#
# Original list: [1, 2, 3]
# Modified list: [10, 2, 3]
#
#
#
# 2.Dictionaries
#
# my_dict = {'a': 1, 'b': 2}
# print("Original dictionary:", my_dict)
#
# my_dict['a'] = 100  # Changing the value associated with key 'a'
# print("Modified dictionary:", my_dict)
#
#
# OUTPUT:-
# Original dictionary: {'a': 1, 'b': 2}
# Modified dictionary: {'a': 100, 'b': 2}
#
#
# 3.Sets
#
# my_set = {1, 2, 3}
# print("Original set:", my_set)
#
# my_set.add(4)  # Adding an element to the set
# print("Modified set:", my_set)
#
#
# OUTPUT:-
# Original set: {1, 2, 3}
# Modified set: {1, 2, 3, 4}
#
#
#
# Immutable Objects
# Immutable objects cannot be changed after they are created. Any modification to an immutable object results in the creation of a new object.
# Common examples of immutable objects in Python include:
#
# .Integers
# .Floats
# .Strings
# .Tuples
#
#
# Examples:
#
# 1. Integers
#
# a = 10
# print("Original integer:", a)
#
# a = a + 5  # This creates a new integer object
# print("New integer:", a)
#
# OUTPUT:-
#
# Original integer: 10
# New integer: 15
#
# 2.Strings
#
# my_str = "hello"
# print("Original string:", my_str)
#
# my_str = my_str.upper()  # This creates a new string object
# print("Modified string:", my_str)
#
# OUTPUT:-
#
# Original string: hello
# Modified string: HELLO
#
# 3.TUPLES
#
# my_tuple = (1, 2, 3)
# print("Original tuple:", my_tuple)
#
# my_tuple = (4,) + my_tuple[1:]  # This creates a new tuple
# print("Modified tuple:", my_tuple)
#
# OUTPUT:-
#
# Original tuple: (1, 2, 3)
# Modified tuple: (4, 2, 3)
#
# #Key Differences
# 1.Modification:
#
# .Mutable: Can be changed in place.
# .Immutable: Cannot be changed; modifications create new objects.
# 2.Performance:
#
# .Mutable: Generally have faster updates since they modify the existing object.
# .Immutable: Can be less efficient for modifications as each change results in a new object creation.
# 3.Use Cases:
#
# .Mutable: Useful when you need to change or update the content frequently, like maintaining a dynamic list of items.
# .Immutable: Ideal for fixed collections of data, ensuring that the data remains consistent and is not accidentally altered.
# .Understanding these concepts helps in making decisions about data structures and their usage in different scenarios,
# ensuring efficient and bug-free code.

# %% [raw]
# 4. Discuss the different types of operators in Python and provide examples of how they are used.
#
#
# In Python, operators are special symbols used to perform operations on variables and values.
# They can be categorized into several types based on their functionality.
# Here’s an overview of the different types of operators in Python, along with examples of how they are used
#
# 1. Arithmetic Operators:-
#
# These operators are used to perform basic arithmetic operations.
#
# Addition ('+'): Adds two values.
#
# a = 5
# b = 3
# print(a + b)
#
# # Output: 8
#
# Subtraction ('-'): Subtracts the second value from the first.
#
# *print(a - b)
#
# # Output: 2
#
#
# Multiplication ('*'): Multiplies two values.
#
# *print(a * b)
#
# # Output: 15
#
# Division ('/'): Divides the first value by the second, resulting in a float.
#
# print(a / b)
#
# # Output: 1.6666666666666667
#
# Floor Division ('//'): Divides and returns the largest integer less than or equal to the result.
#
# print(a//b)
#
# #Output : 1
#
# Modulus ('%'): Returns the remainder of the division.
#
# print(a%b)
#
# #Output:2
#
# Exponentiation ('**'): Raises the first value to the power of the second.
#
# print(a**b)
#
# #Output:125
#
# 2. Comparison Operators
#  These operators compare two values and return a boolean result ('True' or 'False').
#
# .Equal to ('=='): Checks if two values are equal.
#
# x = 10
# y = 20
# print(x == y)
#
# # Output: False
#
# .Not equal to ('!='): Checks if two values are not equal.
#
# print(x != y)
#
# # Output: True
#
# .Greater than ('>'): Checks if the first value is greater than the second
#
# print(x > y)
#
# # Output: False
#
#
# .Less than ('<'): Checks if the first value is less than the second.
#
# print(x < y)
#
# # Output: True
#
# .Greater than or equal to ('>='): Checks if the first value is greater than or equal to the second.
#
# print(x >= y)
#
# # Output: False
#
# .Less than or equal to ('<='): Checks if the first value is less than or equal to the second.
#
# print(x <= y)
#
# # Output: True
#
# 3.Logical Operators
#
# These operators are used to perform logical operations and combine conditional statements.
#
# .Logical AND ('and'): Returns True if both conditions are true.
#
# a = True
# b = False
# print(a and b)
#
# # Output: False
#
#
# .Logical OR ('or'): Returns True if at least one of the conditions is true.
#
#
# print(a or b)
#
# # Output: True
#
# .Logical NOT ('not'): Returns True if the condition is false.
#
#
# print(not a)
#
# # Output: False
#
# 4. Assignment Operators
# These operators are used to assign values to variables.
#
# .Assignment (=): Assigns a value to a variable.
#
# x = 5
#
# .Add and assign ('+='): Adds a value to the variable and assigns the result.
#
#
# x += 3  # Equivalent to x = x + 3
# print(x)
#
# # Output: 8
#
# .Subtract and assign ('-='): Subtracts a value from the variable and assigns the result.
#
#
# x -= 2  # Equivalent to x = x - 2
# print(x)
#
# # Output: 6
#
# .Multiply and assign ('*='): Multiplies the variable by a value and assigns the result.
#
#
# x *= 4  # Equivalent to x = x * 4
# print(x)
#
# # Output: 24
#
# .Divide and assign ('/='): Divides the variable by a value and assigns the result.
#
#
# x /= 3  # Equivalent to x = x / 3
# print(x)
#
# # Output: 8.0
#
# .Floor divide and assign ('//='): Performs floor division and assigns the result.
#
#
# x //= 2  # Equivalent to x = x // 2
# print(x)
#
# # Output: 4.0
#
# .Modulus and assign ('%='): Computes the modulus and assigns the result.
#
#
# x %= 3  # Equivalent to x = x % 3
# print(x)
#
# # Output: 1.0
#
# .Exponentiate and assign ('**='): Raises the variable to a power and assigns the result.
#
#
# x **= 2  # Equivalent to x = x ** 2
# print(x)
#
# # Output: 1.0
#
# 5. Bitwise Operators
# These operators perform bit-level operations on integers.
#
# .Bitwise AND ('&'): Performs a bitwise AND operation.
#
#
# a = 12  # 1100 in binary
# b = 7   # 0111 in binary
# print(a & b)
#
# # Output: 4 (0100 in binary)
#
# .Bitwise OR ('|'): Performs a bitwise OR operation.
#
#
# print(a | b)
#
# # Output: 15 (1111 in binary)
#
#
# Bitwise XOR ('^'): Performs a bitwise XOR operation.
#
# print(a ^ b)
#
# # Output: 11 (1011 in binary)
#
#
# Bitwise NOT ('~'): Performs a bitwise NOT operation (inverts all bits).
#
# print(~a)
#
# # Output: -13 (in binary, it's the bitwise negation of 12)
#
#
# .Bitwise LEFT SHIFT ('<<'): Shifts bits to the left.
#
# print(a << 2)
#
# # Output: 48 (1100 << 2 = 110000 in binary)
#
#
# .Bitwise RIGHT SHIFT ('>>'): Shifts bits to the right.
#
# print(a >> 2)
#
# # Output: 3 (1100 >> 2 = 0011 in binary)
#
# 6. Identity Operators
# These operators compare the memory locations of two objects.
#
# .is: Checks if two references point to the same object.
#
# x = [1, 2, 3]
# y = [1, 2, 3]
# print(x is y)
#
# # Output: False (different objects in memory)
#
# .is not: Checks if two references point to different objects.
#
# print(x is not y)
#
# # Output: True
#
# 7. Membership Operators
# These operators check for membership within a container (like a list, tuple, or string).
#
# .in: Checks if a value is present in a container.
#
# fruits = ['apple', 'banana', 'cherry']
# print('apple' in fruits)
#
# # Output: True
#
#
# .not in: Checks if a value is not present in a container.
#
# print('orange' not in fruits)
#
# # Output: True

# %% [raw]
# 5. Explain the concept of type casting in Python with examples.
#
# Type casting in Python is the process of converting a variable from one data type to another.
# This can be useful when you need to perform operations that require specific data types or when you want to ensure that your data is in the correct format for further processing.
# Python provides several built-in functions to perform type casting.
#
# Here are some common type casting functions and examples:
#
# 1. int()
# .Converts a value to an integer.
#
# # Converting a float to an integer
# num_float = 3.14
# num_int = int(num_float)
# print(num_int)
#
# # Output: 3
#
# # Converting a string to an integer
# num_str = "42"
# num_int = int(num_str)
# print(num_int)
#
# # Output: 42
#
# # Note: If the string cannot be converted to an integer, it will raise a ValueError
#
#
# 2. float()
# .Converts a value to a float.
#
#
#
# # Converting an integer to a float
# num_int = 7
# num_float = float(num_int)
# print(num_float)
#
# # Output: 7.0
#
# # Converting a string to a float
# num_str = "3.14159"
# num_float = float(num_str)
# print(num_float)
#
# # Output: 3.14159
#
# # Note: If the string cannot be converted to a float, it will raise a ValueError
#
#
# 3. str()
# .Converts a value to a string.
#
#
# # Converting an integer to a string
# num_int = 10
# num_str = str(num_int)
# print(num_str)
#
# # Output: "10"
#
# # Converting a float to a string
# num_float = 2.718
# num_str = str(num_float)
# print(num_str)
#
# # Output: "2.718"
#
# 4. list()
# .Converts a value to a list.
#
#
# # Converting a string to a list of characters
# str_value = "hello"
# list_value = list(str_value)
# print(list_value)
#
# # Output: ['h', 'e', 'l', 'l', 'o']
#
# # Converting a tuple to a list
# tuple_value = (1, 2, 3)
# list_value = list(tuple_value)
# print(list_value)
#
# # Output: [1, 2, 3]
#
#
# 5. tuple()
# .Converts a value to a tuple.
#
#
#
# # Converting a list to a tuple
# list_value = [1, 2, 3]
# tuple_value = tuple(list_value)
# print(tuple_value)
#
# # Output: (1, 2, 3)
#
# # Converting a string to a tuple of characters
# str_value = "world"
# tuple_value = tuple(str_value)
# print(tuple_value)
#
# # Output: ('w', 'o', 'r', 'l', 'd')
#
# 6. set()
# Converts a value to a set.
#
#
# # Converting a list to a set
# list_value = [1, 2, 2, 3]
# set_value = set(list_value)
# print(set_value)
#
# # Output: {1, 2, 3}
#
# # Converting a string to a set of characters
# str_value = "banana"
# set_value = set(str_value)
# print(set_value)
#
# # Output: {'a', 'b', 'n'}
#
#
# 7. dict()
# .Converts a value to a dictionary. Typically, you use it with a list of tuples where each tuple represents a key-value pair.
#
#
# # Converting a list of tuples to a dictionary
# list_of_tuples = [('a', 1), ('b', 2), ('c', 3)]
# dict_value = dict(list_of_tuples)
# print(dict_value)
#
# # Output: {'a': 1, 'b': 2, 'c': 3}
#
#
# Important Notes:-
# Implicit Type Conversion: Python performs implicit type conversion automatically in some cases. For example, if you add an integer and a float, Python will automatically convert the integer to a float.
#
#
# result = 5 + 3.2
# print(result)  # Output: 8.2

# %% [raw]
# 6. How do conditional statements work in Python? Illustrate with examples ?
#
#
# 1. if Statement
# .The if statement evaluates a condition (an expression that returns True or False).
# If the condition is True, the code block under the if statement is executed.
#
# age = 18
#
# if age >= 18:
#     print("You are an adult.")
# In this example, since age is 18, which is greater than or equal to 18,
# the condition is True, and the message "You are an adult." is printed.
#
# 2. else Statement
# .The else statement is used to define a block of code that executes if the if condition is False.
#
#
# age = 16
#
# if age >= 18:
#     print("You are an adult.")
# else:
#     print("You are not an adult.")
# Here, since age is 16, which is less than 18, the condition in the if statement is False,
# so the code block under else is executed, and "You are not an adult." is printed.
#
# 3. elif Statement
# .The elif (short for "else if") statement allows you to check multiple conditions.
# It is used when you have more than two conditions to evaluate.
#
#
# score = 85
#
# if score >= 90:
#     print("Grade: A")
# elif score >= 80:
#     print("Grade: B")
# elif score >= 70:
#     print("Grade: C")
# else:
#     print("Grade: D")
# In this case, score is 85, so the condition score >= 80 is True. Therefore, "Grade: B" is printed.
# The other elif and else blocks are not executed.
#
# 4. Nested Conditional Statements
# You can nest conditional statements within other conditional statements to handle more complex scenarios.
#
#
# age = 20
# has_id = True
#
# if age >= 18:
#     if has_id:
#         print("You can enter.")
#     else:
#         print("You need an ID to enter.")
# else:
#     print("You are not old enough to enter.")
# In this example:
#
# The outer if checks if age is at least 18.
# If age is 18 or more, it checks if has_id is True with an inner if.
# Depending on the value of has_id, it prints either "You can enter." or "You need an ID to enter."
#
#
# 5. Boolean Expressions in Conditional Statements
# .Conditional statements can use various comparison operators to form boolean expressions:
#
# Equality: ==
# Inequality: !=
# Greater than: >
# Less than: <
# Greater than or equal to: >=
# Less than or equal to: <=
#
#
# Example:
#
# number = 10
#
# if number > 0 and number < 20:
#     print("The number is between 0 and 20.")
# else:
#     print("The number is not between 0 and 20.")
# Here, number is 10, which satisfies the condition 0 < number < 20, so "The number is between 0 and 20." is printed.
#
# 6. Combining Conditions
# .You can combine multiple conditions using logical operators:
#
# and - True if both conditions are true.
# or - True if at least one condition is true.
# not - True if the condition is false.
# Example:
#
#
# temperature = 30
# is_sunny = True
#
# if temperature > 25 and is_sunny:
#     print("It's a hot and sunny day.")
# elif temperature <= 25 and not is_sunny:
#     print("It's a cool and cloudy day.")
# else:
#     print("Weather conditions are different.")

# %% [raw]
# 7. Describe the different types of loops in Python and their use cases with examples.
#
#
# 1. 'for' Loop
# .The for loop in Python is used to iterate over a sequence of elements, such as lists, tuples, strings, or ranges.
# It is ideal for situations where you need to loop through a known set of values.
#
#
# for variable in sequence:
#     # Code to execute
#
#
# Examples:
# .Iterating Over a List:
#
# fruits = ['apple', 'banana', 'cherry']
#
# for fruit in fruits:
#     print(fruit)
# This loop will print each fruit in the list.
#
# .Iterating Over a Range:
#
# for i in range(5):
#     print(i)
# The range(5) generates numbers from 0 to 4, and the loop prints each number.
#
# .Iterating Over a String:
#
# word = "hello"
#
# for char in word:
#     print(char)
# This loop will print each character in the string "hello".
#
# .Enumerating Elements:
#
# fruits = ['apple', 'banana', 'cherry']
#
# for index, fruit in enumerate(fruits):
#     print(index, fruit)
# The enumerate function adds a counter to the list, allowing access to both the index and the value.
#
# 2. while Loop
# The while loop executes a block of code as long as a condition remains True.
# It is suitable for situations where the number of iterations is not known beforehand and depends on some condition being met.
#
#
# while condition:
#     # Code to execute
# Examples:
# Basic while Loop:
# python
# Copy code
# count = 0
#
# while count < 5:
#     print(count)
#     count += 1
# The loop prints numbers from 0 to 4. The condition count < 5 must be True for the loop to continue, and count is incremented on each iteration.
#
# .Using while with a Condition:
#
# import random
#
# number = random.randint(1, 10)
#
# while number != 7:
#     print("Not 7, try again.")
#     number = random.randint(1, 10)
#
# print("You got 7!")
# This loop continues to generate a random number until it equals 7.
#
# 3. Loop Control Statements
# .Python provides several statements to control the flow of loops:
#
# break: Exits the loop prematurely.
#
# for i in range(10):
#     if i == 5:
#         break
#     print(i)
# .This loop will print numbers from 0 to 4 and stop when i equals 5.
#
# .continue: Skips the rest of the code inside the loop for the current iteration and continues with the next iteration.
#
# for i in range(10):
#     if i % 2 == 0:
#         continue
#     print(i)
# This loop prints only the odd numbers between 0 and 9, skipping the even numbers.
#
# else: Executes a block of code once after the loop finishes, but only if the loop was not terminated by a break statement.
#
#
# for i in range(3):
#     print(i)
# else:
#     print("Loop finished.")
#
# # Output:-
# # 0
# # 1
# # 2
# # Loop finished.
# .The else block runs after the loop completes normally (without hitting a break).
#
# Use Cases
# for Loop Use Cases:
#
# Iterating through items in a list, tuple, or string.
# Iterating over a range of numbers for a known number of iterations.
# Processing each element in a collection (e.g., applying a function to all elements).
# while Loop Use Cases:
